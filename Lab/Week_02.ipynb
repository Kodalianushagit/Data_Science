# %%
#Week 2: Implementation of Data Cleaning techniques.
#Mean / Median / Mode Imputation
import pandas as pd
import numpy as np
df = pd.DataFrame({'Age':[25,30,np.nan,40,35],
                   'Department':['HR','Finance','Finance',np.nan,'IT']})
df_ffill=df.copy()
df_ffill.fillna(method='ffill',inplace=True)
print(df_ffill)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0    Finance
# 4  35.0         IT
# /tmp/ipykernel_6604/1101775679.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill.fillna(method='ffill',inplace=True)

# %%
# Forward Fill
import pandas as pd
import numpy as np
df = pd.DataFrame({'Age':[25,30,np.nan,40,35],
                   'Department':['HR','Finance','Finance',np.nan,'IT']})
df_bfill=df.copy()
df_bfill.fillna(method='bfill',inplace=True)
print(df_bfill)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  40.0    Finance
# 3  40.0         IT
# 4  35.0         IT
# /tmp/ipykernel_6604/2416551693.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill.fillna(method='bfill',inplace=True)

# %%
#backward Fill
import pandas as pd
import numpy as np
df = pd.DataFrame({'Age':[25,30,np.nan,40,35],
                   'Department':['HR','Finance','Finance',np.nan,'IT']})
df_drp_rows=df.dropna()
print("After dropping rows:\n",df_drp_rows)
# Out:
# After dropping rows:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 4  35.0         IT

# %%
#Deletion (drop rows or columns)
# Drop rows with missing values
import pandas as pd
import numpy as np
df = pd.DataFrame({'Age':[25,30,np.nan,40,35],
                   'Department':['HR','Finance','Finance',np.nan,'IT']})
df_drp_cols=df.dropna(axis=1)
print("After dropping columns:\n",df_drp_cols)
# Out:
# After dropping columns:
#  Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# Drop columns with missing values
import pandas as pd
df = pd.DataFrame({
    'Id':[1,2,2,3,4,4,],
    'Name':['Alice','Bob','Bob','Charlie','David','David'],
    'Age':[25,30,35,40,45,50]
})
print("Original Data:\n", df)
df_exact = df.drop_duplicates()
print("\nAfter Exact Match Removal:\n", df_exact)
# Out:
# Original Data:
#     Id     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   35
# 3   3  Charlie   40
# 4   4    David   45
# 5   4    David   50
#
# After Exact Match Removal:
#     Id     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   35
# 3   3  Charlie   40
# 4   4    David   45
# 5   4    David   50

# %%
#Exact Match Removal
df_subset_id = df.drop_duplicates(subset=['Id'])
print("\nAfter Subset-Based Removal (ID):\n", df_subset_id)
df_subset_name = df.drop_duplicates(subset=['Name'])
print("\nAfter Subset-Based Removal (Name):\n", df_subset_name)
# Out:
# After Subset-Based Removal (ID):
#     Id     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   40
# 4   4    David   45
#
# After Subset-Based Removal (Name):
#     Id     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   40
# 4   4    David   45

# %%
#Date Standardization (ISO 8601 format)
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'Date':['2025-01-05','05/01/2025','Jan 5, 2025', '2025.01.05']
})
df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)
# Out:
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
#Date Standardization (ISO 8601 format)
import pandas as pd
df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025', '2025.01.05']
})
df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)

# %%
#Case Normalization (lowercase / uppercase)
df = pd.DataFrame({
    'Name': ['Alice', 'BOB', 'charlie', 'DAVID']
})

# Convert all names to lowercase
df['Name_lower'] = df['Name'].str.lower()

# Convert all names to uppercase
df['Name_upper'] = df['Name'].str.upper()

print(df)
# Out:
#       Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      BOB        bob        BOB
# 2  charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID

# %%
#Vector-Based Distance Measures
import numpy as np
from scipy.spatial import distance

pointA = np.array([2, 4, 6])
pointB = np.array([5, 1, 9])

# Euclidean Distance
euclidean_dist = distance.euclidean(pointA, pointB)
print("Euclidean Distance:", euclidean_dist)

# Similarity (inverse of distance)
similarity_euclidean = 1 / (1 + euclidean_dist)
print("Euclidean Similarity:", similarity_euclidean)
# Out:
# Euclidean Distance: 5.196152422706632
# Euclidean Similarity: 0.16139047779640892

# %%
#Manhattan (City Block) Distance
import numpy as np
from scipy.spatial import distance

manhattan_dist = distance.cityblock(pointA, pointB)
print("Manhattan Distance:", manhattan_dist)

# Similarity (inverse of distance)
similarity_manhattan = 1 / (1 + manhattan_dist)
print("Manhattan Similarity:", similarity_manhattan)
# Out:
# Manhattan Distance: 9
# Manhattan Similarity: 0.1

# %%
#Minkowski Distance (generalized form)
import numpy as np
from scipy.spatial import distance
minkowski_dist_p3 = distance.minkowski(pointA, pointB, p=3)
print("Minkowski Distance (p=3):", minkowski_dist_p3)

# Similarity (inverse of distance)
similarity_minkowski = 1 / (1 + minkowski_dist_p3)
print("Minkowski Similarity (p=3):", similarity_minkowski)
# Out:
# Minkowski Distance (p=3): 4.3267487109222245
# Minkowski Similarity (p=3): 0.1877317767871331

# %%
#Statistical Measures
import pandas as pd
from scipy.stats import pearsonr

# Using an available dataset instead of 'tips.csv'
tips = pd.read_csv("/content/sample_data/california_housing_train.csv")

# Calculate correlation between 'MedInc' and 'HouseAge'
corr, p_value = pearsonr(tips['MedInc'], tips['HouseAge'])

print(f"Pearson correlation coefficient: {corr}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient: -0.1159316246158136
# P-value: 5.967605386815426e-52

# %%
#Spearman Rank Correlation
import pandas as pd
from scipy.stats import spearmanr

# Example dataset
df = pd.DataFrame({
    'X': [10, 20, 30, 40, 50],
    'Y': [12, 18, 33, 47, 55]
})

# Spearman correlation coefficient and p-value
corr_value, p_value = spearmanr(df['X'], df['Y'])
print(f"Spearman Correlation Coefficient: {corr_value}")
print(f"P-value: {p_value}")
# Out:
# Spearman Correlation Coefficient: 0.9999999999999999
# P-value: 1.4042654220543672e-24

# %%
#Edit-Based Measures
def hamming_distance(str1, str2):
    if len(str1) != len(str2):
        raise ValueError("Strings must be of equal length")

    return sum(ch1 != ch2 for ch1, ch2 in zip(str1, str2))

s1 = "karolin"
s2 = "kathrin"

dist = hamming_distance(s1, s2)
print(f"Hamming Distance between '{s1}' and '{s2}': {dist}")
# Out:
# Hamming Distance between 'karolin' and 'kathrin': 3
